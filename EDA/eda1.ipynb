# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

plt.style.use('ggplot')
pd.set_option('max_columns', 200)
pd.set_option('max_rows', 100)
# Out:
# /Users/ericprabowocundomanik/opt/anaconda3/lib/python3.7/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
df = pd.read_csv('data/coaster_db.csv')
df.shape
# Out:
# (1087, 56)

# %%
df.head()
# Out:
#                              coaster_name          Length             Speed  \
# 0                      Switchback Railway  600 ft (180 m)  6 mph (9.7 km/h)
# 1                       Flip Flap Railway             NaN               NaN
# 2  Switchback Railway (Euclid Beach Park)             NaN               NaN
# 3            Loop the Loop (Coney Island)             NaN               NaN
# 4            Loop the Loop (Young's Pier)             NaN               NaN
#
#                          Location   Status   Opening date   Type  \
# 0                    Coney Island  Removed  June 16, 1884   Wood
# 1                   Sea Lion Park  Removed           1895   Wood
# 2  Cleveland, Ohio, United States   Closed            NaN  Other
# 3                           Other  Removed           1901  Steel
# 4                           Other  Removed           1901  Steel
#
#              Manufacturer Height restriction        Model        Height  \
# ...

# %%
df.columns
# Out:
# Index(['coaster_name', 'Length', 'Speed', 'Location', 'Status', 'Opening date',
#        'Type', 'Manufacturer', 'Height restriction', 'Model', 'Height',
#        'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
#        'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
#        'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
#        'Track layout', 'Fastrack available', 'Soft opening date.1',
#        'Closing date', 'Opened', 'Replaced by', 'Website',
#        'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
#        'Single rider line available', 'Restraint Style',
#        'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
#        'year_introduced', 'latitude', 'longitude', 'Type_Main',
#        'opening_date_clean', 'speed1', 'speed2', 'speed1_value', 'speed1_unit',
#        'speed_mph', 'height_value', 'height_unit', 'height_ft',
#        'Inversions_clean', 'Gforce_clean'],
# ...

# %%
df.dtypes
# Out:
# coaster_name                      object
# Length                            object
# Speed                             object
# Location                          object
# Status                            object
# Opening date                      object
# Type                              object
# Manufacturer                      object
# Height restriction                object
# Model                             object
# Height                            object
# Inversions                       float64
# Lift/launch system                object
# Cost                              object
# Trains                            object
# Park section                      object
# Duration                          object
# Capacity                          object
# G-force                           object
# Designer                          object
# Max vertical angle                object
# Drop                              object
# Soft opening date                 object
# ...

# %%
df.describe()
# Out:
#        Inversions  year_introduced    latitude   longitude  speed1_value  \
# count  932.000000      1087.000000  812.000000  812.000000    937.000000
# mean     1.547210      1994.986201   38.373484  -41.595373     53.850374
# std      2.114073        23.475248   15.516596   72.285227     23.385518
# min      0.000000      1884.000000  -48.261700 -123.035700      5.000000
# 25%      0.000000      1989.000000   35.031050  -84.552200     40.000000
# 50%      0.000000      2000.000000   40.289800  -76.653600     50.000000
# 75%      3.000000      2010.000000   44.799600    2.778100     63.000000
# max     14.000000      2022.000000   63.230900  153.426500    240.000000
#
#         speed_mph  height_value   height_ft  Inversions_clean  Gforce_clean
# count  937.000000    965.000000  171.000000       1087.000000    362.000000
# mean    48.617289     89.575171  101.996491          1.326587      3.824006
# std     16.678031    136.246444   67.329092          2.030854      0.989998
# ...

# %%
df_clean = df[['coaster_name', 
    # 'Length', 'Speed', 
    'Location', 'Status', 
    # 'Opening date',
    #    'Type',
    'Manufacturer',
    #   'Height restriction', 'Model', 'Height',
    #    'Inversions', 'Lift/launch system', 'Cost', 'Trains', 'Park section',
    #    'Duration', 'Capacity', 'G-force', 'Designer', 'Max vertical angle',
    #    'Drop', 'Soft opening date', 'Fast Lane available', 'Replaced',
    #    'Track layout', 'Fastrack available', 'Soft opening date.1',
    #    'Closing date', 
    # 'Opened',
    #   'Replaced by', 'Website',
    #    'Flash Pass Available', 'Must transfer from wheelchair', 'Theme',
    #    'Single rider line available', 'Restraint Style',
    #    'Flash Pass available', 'Acceleration', 'Restraints', 'Name',
       'year_introduced', 'latitude', 'longitude', 'Type_Main',
       'opening_date_clean', 
    #    'speed1', 'speed2', 'speed1_value', 'speed1_unit',
       'speed_mph', 
    #    'height_value', 'height_unit', 
       'height_ft',
       'Inversions_clean', 'Gforce_clean'
]]
df_clean
# Out:
#                                 coaster_name                        Location  \
# 0                         Switchback Railway                    Coney Island
# 1                          Flip Flap Railway                   Sea Lion Park
# 2     Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3               Loop the Loop (Coney Island)                           Other
# 4               Loop the Loop (Young's Pier)                           Other
# ...                                      ...                             ...
# 1082                 American Dreier Looping                           Other
# 1083               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 1084               Tron Lightcycle Power Run                           Other
# 1085                                 Tumbili                  Kings Dominion
# 1086          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
print(df_clean[df_clean['Gforce_clean'].isna()].shape)
print(df_clean[~df_clean['Gforce_clean'].isna()].shape)
# Out:
# (725, 13)
# (362, 13)

# %%
df_clean.isna().sum()
# Out:
# coaster_name            0
# Location                0
# Status                213
# Manufacturer           59
# year_introduced         0
# latitude              275
# longitude             275
# Type_Main               0
# opening_date_clean    250
# speed_mph             150
# height_ft             916
# Inversions_clean        0
# Gforce_clean          725
# dtype: int64

# %%
df_clean[df_clean.duplicated()]
# Out:
# Empty DataFrame
# Columns: [coaster_name, Location, Status, Manufacturer, year_introduced, latitude, longitude, Type_Main, opening_date_clean, speed_mph, height_ft, Inversions_clean, Gforce_clean]
# Index: []

# %%
df_clean[df_clean.duplicated(subset=['coaster_name'])]
# Out:
# Empty DataFrame
# Columns: [coaster_name, Location, Status, Manufacturer, year_introduced, latitude, longitude, Type_Main, opening_date_clean, speed_mph, height_ft, Inversions_clean, Gforce_clean]
# Index: []

# %%
df_clean.groupby(['coaster_name']).count().sort_values(['Status'])
# Out:
#                                      Location  Status  Manufacturer  \
# coaster_name
# Zydeco Scream                               1       0             1
# Demon (roller coaster)                      1       0             1
# Klondike Gold Mine (roller coaster)         2       0             2
# Seven Dwarfs Mine Train                     2       0             2
# Timberline Twister                          1       0             0
# ...                                       ...     ...           ...
# Arkham Asylum – Shock Therapy               2       2             2
# Little Dipper (Conneaut Lake Park)          2       2             2
# Raptor Attack                               2       2             2
# Hakugei (roller coaster)                    2       2             2
# Journey to Atlantis                         3       3             3
#
#                                      year_introduced  latitude  longitude  \
# coaster_name
# ...

# %%
df_clean = df_clean.loc[~df_clean.duplicated(subset=['coaster_name', 'Location', 'opening_date_clean'])].reset_index(drop=True).copy()
df_clean
# Out:
#                                coaster_name                        Location  \
# 0                        Switchback Railway                    Coney Island
# 1                         Flip Flap Railway                   Sea Lion Park
# 2    Switchback Railway (Euclid Beach Park)  Cleveland, Ohio, United States
# 3              Loop the Loop (Coney Island)                           Other
# 4              Loop the Loop (Young's Pier)                           Other
# ..                                      ...                             ...
# 985            Ice Breaker (roller coaster)                SeaWorld Orlando
# 986                   Leviathan (Sea World)                       Sea World
# 987               Pantheon (roller coaster)      Busch Gardens Williamsburg
# 988                                 Tumbili                  Kings Dominion
# 989          Wonder Woman Flight of Courage        Six Flags Magic Mountain
#
# ...

# %%
df_clean['year_introduced'].value_counts()
# Out:
# 1999    46
# 2000    45
# 1998    30
# 2001    29
# 2002    28
#         ..
# 1955     1
# 1956     1
# 1959     1
# 1961     1
# 1884     1
# Name: year_introduced, Length: 101, dtype: int64

# %%
ax = df_clean['year_introduced'].value_counts().head(10).plot(kind='bar', title='top years')
ax.set_xlabel('year introduced')
ax.set_ylabel('count')
# Out:
# Text(0, 0.5, 'count')

# %%
ax = df_clean['speed_mph'].plot(kind='hist', bins=20, title='coaster speed')
ax.set_xlabel('speed in mph')
# Out:
# Text(0.5, 0, 'speed in mph')

# %%
ax = df_clean['speed_mph'].plot(kind='kde', title='coaster speed')
ax.set_xlabel('speed in mph')
# Out:
# Text(0.5, 0, 'speed in mph')

# %%
df_clean.plot(
    kind='scatter',
    x='speed_mph', 
    y='height_ft',
    title='coaster speed vs height')
plt.show()

# %%
sns.scatterplot(x='speed_mph', y='height_ft', hue='year_introduced', data=df_clean)

# %%
df_clean.columns
# Out:
# Index(['coaster_name', 'Location', 'Status', 'Manufacturer', 'year_introduced',
#        'latitude', 'longitude', 'Type_Main', 'opening_date_clean', 'speed_mph',
#        'height_ft', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
sns.pairplot(data=df_clean, hue='Type_Main', vars=[
    'year_introduced', 'speed_mph', 'height_ft',
    'Inversions_clean', 'Gforce_clean'
])
plt.show()
# Out:
# /Users/ericprabowocundomanik/opt/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:447: RuntimeWarning: invalid value encountered in greater
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.
# /Users/ericprabowocundomanik/opt/anaconda3/lib/python3.7/site-packages/statsmodels/nonparametric/kde.py:447: RuntimeWarning: invalid value encountered in less
#   X = X[np.logical_and(X > clip[0], X < clip[1])] # won't work for two columns.

# %%
df_corr = df_clean[['year_introduced', 'speed_mph', 'height_ft', \
          'Inversions_clean', 'Gforce_clean']] \
            .dropna() \
            .corr()
df_corr
# Out:
#                   year_introduced  speed_mph  height_ft  Inversions_clean  \
# year_introduced          1.000000   0.171978   0.135413         -0.209887
# speed_mph                0.171978   1.000000   0.733999         -0.028705
# height_ft                0.135413   0.733999   1.000000         -0.079736
# Inversions_clean        -0.209887  -0.028705  -0.079736          1.000000
# Gforce_clean             0.160247   0.607383   0.466482          0.275991
#
#                   Gforce_clean
# year_introduced       0.160247
# speed_mph             0.607383
# height_ft             0.466482
# Inversions_clean      0.275991
# Gforce_clean          1.000000

# %%
sns.heatmap(data=df_corr, annot=True)

# %% [markdown]
# ### answer questions:
# ##### 1. What are locations with the fastest roller coasters (minimum of 10)?

# %%
df_clean.columns
# Out:
# Index(['coaster_name', 'Location', 'Status', 'Manufacturer', 'year_introduced',
#        'latitude', 'longitude', 'Type_Main', 'opening_date_clean', 'speed_mph',
#        'height_ft', 'Inversions_clean', 'Gforce_clean'],
#       dtype='object')

# %%
df_clean.query('Location != "Other"') \
    .groupby('Location')['speed_mph'] \
    .agg(['mean', 'count']) \
    .query('count >= 10') \
    .sort_values('mean')['mean'] \
    .plot(kind='barh', figsize=(12, 5), title='Average Coast Speed by Location')
